# %% [markdown]
# # Data Space Report
#
#
# <img src="images/polito_logo.png" alt="Polito Logo" style="width: 200px;"/>
#
#
# ## Pittsburgh Bridges Data Set
#
# <img src="images/andy_warhol_bridge.jpg" alt="Andy Warhol Bridge" style="width: 200px;"/>
#
#     Andy Warhol Bridge - Pittsburgh.
#
# Report created by Student Francesco Maria Chiarlo s253666, for A.A 2019/2020.
#
# **Abstract**:The aim of this report is to evaluate the effectiveness of distinct, different statistical learning approaches, in particular focusing on their characteristics as well as on their advantages and backwards when applied onto a relatively small dataset as the one employed within this report, that is Pittsburgh Bridgesdataset.
#
# **Key words**:Statistical Learning, Machine Learning, Bridge Design.

# %% [markdown]
# ### Imports Section <a class="anchor" id="imports-section"></a>

# %%
# =========================================================================== #
# STANDARD IMPORTS
# =========================================================================== #
print(__doc__)

from pprint import pprint
from itertools import islice

import warnings
warnings.filterwarnings('ignore')

import copy; import os
import sys; import time
import itertools

import numpy as np; import pandas as pd

# %matplotlib inline
# Matplotlib pyplot provides plotting API
import matplotlib as mpl
from matplotlib import pyplot as plt
import chart_studio.plotly.plotly as py
import seaborn as sns;  sns.set(style="ticks", color_codes=True) # sns.set()
# Out:
# Automatically created module for IPython interactive environment

# %%
# =========================================================================== #
# UTILS IMPORTS (Done by myself)
# =========================================================================== #
from utils.load_dataset_pittsburg_utils import load_brdiges_dataset
from utils.display_utils import *
from utils.preprocessing_utils import *
from utils.training_utils import *
from utils.training_utils_v2 import fit_by_n_components, fit_all_by_n_components, grid_search_all_by_n_components

# %%
# =========================================================================== #
# sklearn IMPORT
# =========================================================================== #
from sklearn.decomposition import PCA, KernelPCA

# Import scikit-learn classes: models (Estimators).
from sklearn.naive_bayes import GaussianNB           # Non-parametric Generative Model
from sklearn.naive_bayes import MultinomialNB        # Non-parametric Generative Model
from sklearn.linear_model import LinearRegression    # Parametric Linear Discriminative Model
from sklearn.linear_model import LogisticRegression  # Parametric Linear Discriminative Model
from sklearn.linear_model import Ridge, Lasso, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC                          # Parametric Linear Discriminative "Support Vector Classifier"
from sklearn.tree import DecisionTreeClassifier      # Non-parametric Model
from sklearn.ensemble import BaggingClassifier       # Non-parametric Model (Meta-Estimator, that is, an Ensemble Method)
from sklearn.ensemble import RandomForestClassifier  # Non-parametric Model (Meta-Estimator, that is, an Ensemble Method)

# %%
# =========================================================================== #
# READ INPUT DATASET
# =========================================================================== #

dataset_path = 'C:\\Users\\Francesco\Documents\\datasets\\pittsburgh_dataset'
dataset_name = 'bridges.data.csv'

TARGET_COL = 'T-OR-D'  
dataset = load_brdiges_dataset(dataset_path, dataset_name)

# %%
columns_2_avoid = ['ERECTED', 'LENGTH', 'LOCATION']
target_col = 'T-OR-D'

# %%
# Make distinction between Target Variable and Predictors
# --------------------------------------------------------------------------- #

columns = dataset.columns  # List of all attribute names
target_col = 'T-OR-D'      # Target variable name

# Get Target values and map to 0s and 1s
y = np.array(list(map(lambda x: 0 if x == 1 else 1, dataset[target_col].values)))
print('Summary about Target Variable {target_col}')
print('-' * 50)
print(dataset['T-OR-D'].value_counts())

# Get Predictors
X = dataset.loc[:, dataset.columns != target_col].values
# Out:
# Summary about Target Variable {target_col}
# --------------------------------------------------
# 2    57
# 1    13
# Name: T-OR-D, dtype: int64

# %%
# Standardizing the features
# --------------------------------------------------------------------------- #
scaler_methods = ['minmax', 'standard', 'norm']
scaler_method = 'standard'
rescaledX = preprocessing_data_rescaling(scaler_method, X)
# Out:
# shape features matrix X, after normalizing:  (70, 11)

# %% [markdown]
# ## Pricipal Component Analysis

# %%
n_components = rescaledX.shape[1]
pca = PCA(n_components=n_components)
# pca = PCA(n_components=2)

# X_pca = pca.fit_transform(X)
pca = pca.fit(rescaledX)
X_pca = pca.transform(rescaledX)

# %%
print(f"Cumulative varation explained(percentage) up to given number of pcs:")

tmp_data = []
principal_components = [pc for pc in '2,5,6,7,8,9,10'.split(',')]
for _, pc in enumerate(principal_components):
    n_components = int(pc)
    
    cum_var_exp_up_to_n_pcs = np.cumsum(pca.explained_variance_ratio_)[n_components-1]
    # print(f"Cumulative varation explained up to {n_components} pcs = {cum_var_exp_up_to_n_pcs}")
    # print(f"# pcs {n_components}: {cum_var_exp_up_to_n_pcs*100:.2f}%")
    tmp_data.append([n_components, cum_var_exp_up_to_n_pcs * 100])

tmp_df = pd.DataFrame(data=tmp_data, columns=['# PCS', 'Cumulative Varation Explained (percentage)'])
tmp_df.head(len(tmp_data))
# Out:
# Cumulative varation explained(percentage) up to given number of pcs:
#    # PCS  Cumulative Varation Explained (percentage)
# 0      2                                   47.738342
# 1      5                                   75.856460
# 2      6                                   82.615768
# 3      7                                   88.413903
# 4      8                                   92.661938
# 5      9                                   95.976841
# 6     10                                   98.432807

# %% [markdown]
# #### Major Pros & Cons of PCA

# %% [markdown]
# ## Learning Models <a class="anchor" id="learning-models"></a>

# %%
# Parameters to be tested for Cross-Validation Approach

estimators_list = [GaussianNB(), LogisticRegression(), KNeighborsClassifier(), SGDClassifier(), SVC(), DecisionTreeClassifier(), RandomForestClassifier()]
estimators_names = ['GaussianNB', 'LogisticRegression', 'KNeighborsClassifier', 'SGDClassifier', 'SVC', 'DecisionTreeClassifier', 'RandomForestClassifier']
plots_names = list(map(lambda xi: f"{xi}_learning_curve.png", estimators_names))

pca_kernels_list = ['linear', 'poly', 'rbf', 'cosine',]
cv_list = [10, 9, 8, 7, 6, 5, 4, 3, 2]

parmas_logistic_regression = {
    'penalty': ('l1', 'l2', 'elastic'),
    'solver': ('newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'),
    'fit_intercept': (True, False),
    'tol': (1e-4, 1e-3, 1e-2),
    'C': (1.0, .1, .01, .001),
}

parmas_knn_forest = {
    'n_neighbors': (2,3,4,5,6,7,8,9,10),
    'weights': ('uniform', 'distance'),
    'algorithm': ('ball_tree', 'kd_tree', 'brute'),
}

parameters_sgd_classifier = {
    'loss': ('log', 'modified_huber'), # ('hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron')
    'penalty': ('l2', 'l1', 'elasticnet'),
    'alpha': (1e-1, 1e-2, 1e-3, 1e-4),
    'max_iter': (50, 100, 150, 200, 500, 1000, 1500, 2000, 2500),
    'learning_rate': ('optimal',),
    'tol': (None, 1e-2, 1e-4, 1e-5, 1e-6)
}

kernel_type = 'svm-rbf-kernel'
parameters_svm = {
    'gamma': (0.003, 0.03, 0.05, 0.5, 0.7, 1.0, 1.5),
    'max_iter':(1e+2, 1e+3, 2 * 1e+3, 5 * 1e+3, 1e+4, 1.5 * 1e+3),
    # 'penalty': ('l2','l1'),
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid',],
    'C': (1e-4, 1e-3, 1e-2, 0.1, 1.0, 10, 1e+2, 1e+3),
    'probability': (True,), 
}

parmas_decision_tree = {
    'splitter': ('random', 'best'),
    'criterion':('gini', 'entropy'),
    'max_features': (None, 'auto', 'sqrt', 'log2')
}

parmas_random_forest = {
    'n_estimators': (3, 5, 7, 10, 30, 50, 70, 100, 150, 200),
    'criterion':('gini', 'entropy'),
    'bootstrap': (True, False)
}

param_grids = [parmas_logistic_regression, parmas_knn_forest, parameters_sgd_classifier, parameters_svm, parmas_decision_tree, parmas_random_forest]

N_CV, N_KERNEL, N_GS = 9, 4, 6
assert len(cv_list) >= N_CV, f"Error: N_CV={N_CV} > len(cv_list)={len(cv_list)}"
assert len(pca_kernels_list) >= N_KERNEL, f"Error: N_KERNEL={N_KERNEL} > len(pca_kernels_list)={len(pca_kernels_list)}"
assert len(param_grids) >= N_GS, f"Error: N_GS={N_GS} > len(param_grids)={len(param_grids)}"

# %%
plot_dest = os.path.join("figures", "n_comp_9_analysis", "grid_search")
X = rescaledX

df_grid_searches = grid_search_all_by_n_components(
    estimators_list=estimators_list[1:N_GS+1], \
    param_grids=param_grids[:N_GS],
    estimators_names=estimators_names[1:N_GS], \
    X=X, y=y,
    n_components=9,
    random_state=0, show_plots=False, show_errors=False, verbose=0, plot_dest=plot_dest, debug_var=False)
print(df_grid_searches)
# Out:
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55         6
#            1       1.00      0.64      0.78        28
#
#     accuracy                           0.71        34
#    macro avg       0.69      0.82      0.66        34
# weighted avg       0.89      0.71      0.74        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55         6
#            1       1.00      0.64      0.78        28
#
#     accuracy                           0.71        34
#    macro avg       0.69      0.82      0.66        34
# weighted avg       0.89      0.71      0.74        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55         6
#            1       1.00      0.64      0.78        28
#
#     accuracy                           0.71        34
#    macro avg       0.69      0.82      0.66        34
# weighted avg       0.89      0.71      0.74        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.33      0.29         6
#            1       0.85      0.79      0.81        28
#
#     accuracy                           0.71        34
#    macro avg       0.55      0.56      0.55        34
# weighted avg       0.74      0.71      0.72        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.33      0.29         6
#            1       0.85      0.79      0.81        28
#
#     accuracy                           0.71        34
#    macro avg       0.55      0.56      0.55        34
# weighted avg       0.74      0.71      0.72        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.33      0.29         6
#            1       0.85      0.79      0.81        28
#
#     accuracy                           0.71        34
#    macro avg       0.55      0.56      0.55        34
# weighted avg       0.74      0.71      0.72        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.19      1.00      0.32         6
#            1       1.00      0.11      0.19        28
#
#     accuracy                           0.26        34
#    macro avg       0.60      0.55      0.26        34
# weighted avg       0.86      0.26      0.22        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.19      1.00      0.32         6
#            1       1.00      0.11      0.19        28
#
#     accuracy                           0.26        34
#    macro avg       0.60      0.55      0.26        34
# weighted avg       0.86      0.26      0.22        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.19      1.00      0.32         6
#            1       1.00      0.11      0.19        28
#
#     accuracy                           0.26        34
#    macro avg       0.60      0.55      0.26        34
# weighted avg       0.86      0.26      0.22        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.83      0.53         6
#            1       0.95      0.71      0.82        28
#
#     accuracy                           0.74        34
#    macro avg       0.67      0.77      0.67        34
# weighted avg       0.85      0.74      0.77        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.18      1.00      0.30         6
#            1       0.00      0.00      0.00        28
#
#     accuracy                           0.18        34
#    macro avg       0.09      0.50      0.15        34
# weighted avg       0.03      0.18      0.05        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.83      0.53         6
#            1       0.95      0.71      0.82        28
#
#     accuracy                           0.74        34
#    macro avg       0.67      0.77      0.67        34
# weighted avg       0.85      0.74      0.77        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.83      0.38         6
#            1       0.93      0.46      0.62        28
#
#     accuracy                           0.53        34
#    macro avg       0.59      0.65      0.50        34
# weighted avg       0.81      0.53      0.58        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.83      0.38         6
#            1       0.93      0.46      0.62        28
#
#     accuracy                           0.53        34
#    macro avg       0.59      0.65      0.50        34
# weighted avg       0.81      0.53      0.58        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.83      0.38         6
#            1       0.93      0.46      0.62        28
#
#     accuracy                           0.53        34
#    macro avg       0.59      0.65      0.50        34
# weighted avg       0.81      0.53      0.58        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.83      0.53         6
#            1       0.95      0.71      0.82        28
#
#     accuracy                           0.74        34
#    macro avg       0.67      0.77      0.67        34
# weighted avg       0.85      0.74      0.77        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.83      0.53         6
#            1       0.95      0.71      0.82        28
#
#     accuracy                           0.74        34
#    macro avg       0.67      0.77      0.67        34
# weighted avg       0.85      0.74      0.77        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.83      0.53         6
#            1       0.95      0.71      0.82        28
#
#     accuracy                           0.74        34
#    macro avg       0.67      0.77      0.67        34
# weighted avg       0.85      0.74      0.77        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.67      0.53         6
#            1       0.92      0.82      0.87        28
#
#     accuracy                           0.79        34
#    macro avg       0.68      0.74      0.70        34
# weighted avg       0.84      0.79      0.81        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.67      0.53         6
#            1       0.92      0.82      0.87        28
#
#     accuracy                           0.79        34
#    macro avg       0.68      0.74      0.70        34
# weighted avg       0.84      0.79      0.81        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.67      0.53         6
#            1       0.92      0.82      0.87        28
#
#     accuracy                           0.79        34
#    macro avg       0.68      0.74      0.70        34
# weighted avg       0.84      0.79      0.81        34
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.67      0.36         6
#            1       0.89      0.57      0.70        28
#
#     accuracy                           0.59        34
#    macro avg       0.57      0.62      0.53        34
# weighted avg       0.78      0.59      0.64        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.67      0.36         6
#            1       0.89      0.57      0.70        28
#
#     accuracy                           0.59        34
#    macro avg       0.57      0.62      0.53        34
# weighted avg       0.78      0.59      0.64        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.21      0.50      0.30         6
#            1       0.85      0.61      0.71        28
#
#     accuracy                           0.59        34
#    macro avg       0.53      0.55      0.50        34
# weighted avg       0.74      0.59      0.64        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.22      1.00      0.36         6
#            1       1.00      0.25      0.40        28
#
#     accuracy                           0.38        34
#    macro avg       0.61      0.62      0.38        34
# weighted avg       0.86      0.38      0.39        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.30      1.00      0.46         6
#            1       1.00      0.50      0.67        28
#
#     accuracy                           0.59        34
#    macro avg       0.65      0.75      0.56        34
# weighted avg       0.88      0.59      0.63        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.19      1.00      0.32         6
#            1       1.00      0.11      0.19        28
#
#     accuracy                           0.26        34
#    macro avg       0.60      0.55      0.26        34
# weighted avg       0.86      0.26      0.22        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.35      1.00      0.52         6
#            1       1.00      0.61      0.76        28
#
#     accuracy                           0.68        34
#    macro avg       0.68      0.80      0.64        34
# weighted avg       0.89      0.68      0.71        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.28      0.83      0.42         6
#            1       0.94      0.54      0.68        28
#
#     accuracy                           0.59        34
#    macro avg       0.61      0.68      0.55        34
# weighted avg       0.82      0.59      0.64        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.30      1.00      0.46         6
#            1       1.00      0.50      0.67        28
#
#     accuracy                           0.59        34
#    macro avg       0.65      0.75      0.56        34
# weighted avg       0.88      0.59      0.63        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.82      0.96      0.89        28
#
#     accuracy                           0.79        34
#    macro avg       0.41      0.48      0.44        34
# weighted avg       0.67      0.79      0.73        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.43      1.00      0.60         6
#            1       1.00      0.71      0.83        28
#
#     accuracy                           0.76        34
#    macro avg       0.71      0.86      0.72        34
# weighted avg       0.90      0.76      0.79        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44         6
#            1       0.87      0.96      0.92        28
#
#     accuracy                           0.85        34
#    macro avg       0.77      0.65      0.68        34
# weighted avg       0.83      0.85      0.83        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.36      0.67      0.47         6
#            1       0.91      0.75      0.82        28
#
#     accuracy                           0.74        34
#    macro avg       0.64      0.71      0.65        34
# weighted avg       0.82      0.74      0.76        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.27      1.00      0.43         6
#            1       1.00      0.43      0.60        28
#
#     accuracy                           0.53        34
#    macro avg       0.64      0.71      0.51        34
# weighted avg       0.87      0.53      0.57        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         6
#            1       1.00      0.57      0.73        28
#
#     accuracy                           0.65        34
#    macro avg       0.67      0.79      0.61        34
# weighted avg       0.88      0.65      0.69        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.83      0.48         6
#            1       0.95      0.64      0.77        28
#
#     accuracy                           0.68        34
#    macro avg       0.64      0.74      0.62        34
# weighted avg       0.84      0.68      0.71        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.83      0.48         6
#            1       0.95      0.64      0.77        28
#
#     accuracy                           0.68        34
#    macro avg       0.64      0.74      0.62        34
# weighted avg       0.84      0.68      0.71        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.83      0.48         6
#            1       0.95      0.64      0.77        28
#
#     accuracy                           0.68        34
#    macro avg       0.64      0.74      0.62        34
# weighted avg       0.84      0.68      0.71        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.27      0.67      0.38         6
#            1       0.89      0.61      0.72        28
#
#     accuracy                           0.62        34
#    macro avg       0.58      0.64      0.55        34
# weighted avg       0.78      0.62      0.66        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.27      0.67      0.38         6
#            1       0.89      0.61      0.72        28
#
#     accuracy                           0.62        34
#    macro avg       0.58      0.64      0.55        34
# weighted avg       0.78      0.62      0.66        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.27      0.67      0.38         6
#            1       0.89      0.61      0.72        28
#
#     accuracy                           0.62        34
#    macro avg       0.58      0.64      0.55        34
# weighted avg       0.78      0.62      0.66        34
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.25         6
#            1       0.84      0.96      0.90        28
#
#     accuracy                           0.82        34
#    macro avg       0.67      0.57      0.57        34
# weighted avg       0.78      0.82      0.79        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         6
#            1       0.93      0.93      0.93        28
#
#     accuracy                           0.88        34
#    macro avg       0.80      0.80      0.80        34
# weighted avg       0.88      0.88      0.88        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.25         6
#            1       0.84      0.96      0.90        28
#
#     accuracy                           0.82        34
#    macro avg       0.67      0.57      0.57        34
# weighted avg       0.78      0.82      0.79        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.17      0.17      0.17         6
#            1       0.82      0.82      0.82        28
#
#     accuracy                           0.71        34
#    macro avg       0.49      0.49      0.49        34
# weighted avg       0.71      0.71      0.71        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40         6
#            1       1.00      0.36      0.53        28
#
#     accuracy                           0.47        34
#    macro avg       0.62      0.68      0.46        34
# weighted avg       0.87      0.47      0.50        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.17      0.17      0.17         6
#            1       0.82      0.82      0.82        28
#
#     accuracy                           0.71        34
#    macro avg       0.49      0.49      0.49        34
# weighted avg       0.71      0.71      0.71        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.30      0.50      0.37         6
#            1       0.88      0.75      0.81        28
#
#     accuracy                           0.71        34
#    macro avg       0.59      0.62      0.59        34
# weighted avg       0.77      0.71      0.73        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.22      0.33      0.27         6
#            1       0.84      0.75      0.79        28
#
#     accuracy                           0.68        34
#    macro avg       0.53      0.54      0.53        34
# weighted avg       0.73      0.68      0.70        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.32      1.00      0.48         6
#            1       1.00      0.54      0.70        28
#
#     accuracy                           0.62        34
#    macro avg       0.66      0.77      0.59        34
# weighted avg       0.88      0.62      0.66        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.36      0.83      0.50         6
#            1       0.95      0.68      0.79        28
#
#     accuracy                           0.71        34
#    macro avg       0.65      0.76      0.65        34
# weighted avg       0.85      0.71      0.74        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.21      1.00      0.35         6
#            1       1.00      0.21      0.35        28
#
#     accuracy                           0.35        34
#    macro avg       0.61      0.61      0.35        34
# weighted avg       0.86      0.35      0.35        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         6
#            1       1.00      0.57      0.73        28
#
#     accuracy                           0.65        34
#    macro avg       0.67      0.79      0.61        34
# weighted avg       0.88      0.65      0.69        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.28      0.83      0.42         6
#            1       0.94      0.54      0.68        28
#
#     accuracy                           0.59        34
#    macro avg       0.61      0.68      0.55        34
# weighted avg       0.82      0.59      0.64        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.80      0.86      0.83        28
#
#     accuracy                           0.71        34
#    macro avg       0.40      0.43      0.41        34
# weighted avg       0.66      0.71      0.68        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.81      0.89      0.85        28
#
#     accuracy                           0.74        34
#    macro avg       0.40      0.45      0.42        34
# weighted avg       0.66      0.74      0.70        34
#
#
# # Tuning hyper-parameters for precision
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.71      0.54      0.61        28
#
#     accuracy                           0.44        34
#    macro avg       0.36      0.27      0.31        34
# weighted avg       0.59      0.44      0.50        34
#
#
# # Tuning hyper-parameters for recall
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.26      0.83      0.40         6
#            1       0.93      0.50      0.65        28
#
#     accuracy                           0.56        34
#    macro avg       0.60      0.67      0.53        34
# weighted avg       0.82      0.56      0.61        34
#
#
# # Tuning hyper-parameters for f1
#
# Grid scores on development set:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.77      0.71      0.74        28
#
#     accuracy                           0.59        34
#    macro avg       0.38      0.36      0.37        34
# weighted avg       0.63      0.59      0.61        34
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6635560b5fda> in <module>
#       8     X=X, y=y,
#       9     n_components=9,
# ---> 10     random_state=0, show_plots=False, show_errors=False, verbose=0, plot_dest=plot_dest, debug_var=False)
#      11 print(df_grid_searches)
#
# ~\PycharmProjects\Pittsburgh-Bridge-Dataset\pittsburgh-bridges-data-set-analysis\utils\training_utils_v2.py in grid_search_all_by_n_components(estimators_list, param_grids, estimators_names, X, y, n_components, pca_kernels_list, random_state, show_plots, show_errors, verbose, plot_dest, debug_var)
#     669             grid_res = grid_search_by_n_components(estimator_obj, param_grids[ii], X, y, n_components, estimator_name, kernels_list=pca_kernels_list, random_state=0, show_plots=False, show_errors=False, verbose=verbose, plot_dest=plot_dest_list[ii], estimator_name=estimator_name)
#     670             grid_res_list.append(grid_res)
# --> 671     df_grid_searches = prepare_output_df_grid_search(grid_res_list, pca_kernels_list, estimators_names)
#     672     return df_grid_searches
#     673
#
# ~\PycharmProjects\Pittsburgh-Bridge-Dataset\pittsburgh-bridges-data-set-analysis\utils\utilities_functions.py in prepare_output_df_grid_search(grid_searchs, pca_kernels, estimator_names)
#     215     for _, a_grid_search in enumerate(grid_searchs):
#     216         tmp_res = []
# --> 217         for _, (a_grid, _) in enumerate(a_grid_search):
#     218             tmp_res.append("%.2f" % (a_grid.best_score_,))
#     219             pass
#
# ValueError: too many values to unpack (expected 2)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

print(__doc__)

# Loading the Digits dataset
digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(digits.images)
X = digits.images.reshape((n_samples, -1))
y = digits.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        SVC(), tuned_parameters, scoring='%s_macro' % score
    )
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()

# %% [markdown]
# ### Improvements and Conclusions <a class="anchor" id="Improvements-and-conclusions"></a>

# %% [markdown]
# ### References  <a class="anchor" id="references"></a>
# - Data Domain Information part:
#     - (Deck) https://en.wikipedia.org/wiki/Deck_(bridge)
#     - (Cantilever bridge) https://en.wikipedia.org/wiki/Cantilever_bridge
#     - (Arch bridge) https://en.wikipedia.org/wiki/Deck_(bridge)
# - Machine Learning part:
#     - (Theory Book) https://jakevdp.github.io/PythonDataScienceHandbook/
#     - (Decsion Trees) https://scikit-learn.org/stable/modules/tree.html#tree
#     - (SVM) https://scikit-learn.org/stable/modules/svm.html
#     - (PCA) https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
# - Chart part:
#     - (Seaborn Charts) https://acadgild.com/blog/data-visualization-using-matplotlib-and-seaborn
# - Markdown Math part:
#     - https://share.cocalc.com/share/b4a30ed038ee41d868dad094193ac462ccd228e2/Homework%20/HW%201.2%20-%20Markdown%20and%20LaTeX%20Cheatsheet.ipynb?viewer=share
#     - https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html
#
# #### others
# - Plots:
#     - (Python Plot) https://www.datacamp.com/community/tutorials/matplotlib-tutorial-python?utm_source=adwords_ppc&utm_campaignid=898687156&utm_adgroupid=48947256715&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=255798340456&utm_targetid=aud-299261629574:dsa-473406587955&utm_loc_interest_ms=&utm_loc_physical_ms=1008025&gclid=Cj0KCQjw-_j1BRDkARIsAJcfmTFu4LAUDhRGK2D027PHiqIPSlxK3ud87Ek_lwOu8rt8A8YLrjFiHqsaAoLDEALw_wcB
# - Third Party Library:
#     - (statsmodels) https://www.statsmodels.org/stable/index.html#
# - KDE:
#     - (TUTORIAL) https://jakevdp.github.io/blog/2013/12/01/kernel-density-estimation/
# - Metrics:
#     - (F1-Accuracy-Precision-Recall) https://towardsdatascience.com/beyond-accuracy-precision-and-recall-3da06bea9f6c
